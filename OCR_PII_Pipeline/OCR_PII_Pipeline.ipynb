# %% [markdown]
# # OCR + PII Extraction Notebook
# This notebook contains the steps to run the OCR -> PII pipeline on the provided handwritten images.
# Run each cell in order. Ensure you have installed the dependencies in `requirements.txt` and downloaded the spaCy model.

# %%
import cv2, numpy as np, easyocr, spacy, re
from pathlib import Path
print('Imports ok')

# %%
# Replace with the path to the images in your environment
images = ['page_35.jpg','page_30.jpg','page_14.jpg']
for im in images:
    print('Image:', im)

# %% [markdown]
# ### Notes
# - If running on this environment, make sure EasyOCR and spaCy are installed.
# - To download spaCy model: `python -m spacy download en_core_web_sm`
